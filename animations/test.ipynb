# %% [markdown]
# from IPython.display import Image

# %%
# !pip install ipython

# %%
from IPython.display import Image

# %%
Image(url='/home/hpcnc/intern-research/animations/01_learning_progress.gif')
